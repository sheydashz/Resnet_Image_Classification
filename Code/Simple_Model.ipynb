# %%
import keras
from keras.datasets import cifar10
from keras.utils import np_utils
import numpy as np
from keras.models import Sequential
from keras.layers import Conv2D,Activation,BatchNormalization,MaxPooling2D,Dropout,Flatten,Dense,AveragePooling2D
from keras.preprocessing.image import ImageDataGenerator
from keras import regularizers
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')

#z-score
mean = np.mean(x_train,axis=(0,1,2,3))
std = np.std(x_train,axis=(0,1,2,3))
x_train = (x_train-mean)/(std+1e-7)
x_test = (x_test-mean)/(std+1e-7)

num_classes = 10
y_train = np_utils.to_categorical(y_train,num_classes)
y_test = np_utils.to_categorical(y_test,num_classes)

weight_decay = 1e-4
model = Sequential()
model.add(Conv2D(32, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay), input_shape=x_train.shape[1:],activation='elu'))
model.add(BatchNormalization())
model.add(Conv2D(32, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(BatchNormalization())
model.add(Activation('elu'))
model.add(AveragePooling2D(pool_size=(2,2)))
model.add(Conv2D(32, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay),activation='elu'))
model.add(BatchNormalization())
model.add(Dropout(0.3))

model.add(Conv2D(64, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay),activation='elu'))
model.add(BatchNormalization())
model.add(Conv2D(64,(3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay),activation='elu'))
model.add(BatchNormalization())
model.add(AveragePooling2D(pool_size=(2,2)))
model.add(Dropout(0.3))

model.add(Conv2D(128, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay),activation='elu'))
model.add(BatchNormalization())
model.add(Conv2D(128, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))

model.add(Flatten())
model.add(Dense(num_classes, activation='softmax'))

model.summary()

#data augmentation
datagen = ImageDataGenerator(
    featurewise_center=False,
    samplewise_center=False,
    featurewise_std_normalization=False,
    samplewise_std_normalization=False,
    zca_whitening=False,
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    vertical_flip=False
    )
datagen.fit(x_train)

#training
batch_size = 64
epochs=30
opt_rms = keras.optimizers.Adam(lr=1e-3,decay=1e-6)
model.compile(loss='categorical_crossentropy',
        optimizer=opt_rms,
        metrics=['accuracy'])
model.fit_generator(datagen.flow(x_train, y_train, batch_size=batch_size),steps_per_epoch=x_train.shape[0] // batch_size,epochs=3*epochs,verbose=1,validation_data=(x_test,y_test))

opt = keras.optimizers.Adam(lr=1e-4,decay=1e-6)
model.compile(loss='categorical_crossentropy',
        optimizer=opt_rms,
        metrics=['accuracy'])
model.fit_generator(datagen.flow(x_train, y_train, batch_size=batch_size),steps_per_epoch=x_train.shape[0] // batch_size,epochs=epochs,verbose=1,validation_data=(x_test,y_test))

opt_rms = keras.optimizers.Adam(lr=1e-5,decay=1e-6)
model.compile(loss='categorical_crossentropy',
        optimizer=opt_rms,
        metrics=['accuracy'])
model.fit_generator(datagen.flow(x_train, y_train, batch_size=batch_size),steps_per_epoch=x_train.shape[0] // batch_size,epochs=epochs,verbose=1,validation_data=(x_test,y_test))
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_8 (Conv2D)            (None, 32, 32, 32)        896
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# activation_3 (Activation)    (None, 32, 32, 32)        0
# _________________________________________________________________
# average_pooling2d_3 (Average (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 16, 16, 32)        9248
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 16, 16, 32)        128
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 16, 16, 64)        18496
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 16, 16, 64)        256
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 16, 16, 64)        36928
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 16, 16, 64)        256
# _________________________________________________________________
# average_pooling2d_4 (Average (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 8, 8, 128)         73856
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 8, 8, 128)         512
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 8, 8, 128)         147584
# _________________________________________________________________
# activation_4 (Activation)    (None, 8, 8, 128)         0
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 8, 8, 128)         512
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                20490
# =================================================================
# Total params: 318,666
# Trainable params: 317,706
# Non-trainable params: 960
# _________________________________________________________________
# Epoch 1/90
# 781/781 [==============================] - 36s 46ms/step - loss: 2.0551 - acc: 0.3615 - val_loss: 1.4228 - val_acc: 0.5188
# Epoch 2/90
# 781/781 [==============================] - 35s 45ms/step - loss: 1.5109 - acc: 0.4950 - val_loss: 1.1403 - val_acc: 0.6232
# Epoch 3/90
# 781/781 [==============================] - 35s 45ms/step - loss: 1.2868 - acc: 0.5675 - val_loss: 1.0627 - val_acc: 0.6583
# Epoch 4/90
# 781/781 [==============================] - 35s 45ms/step - loss: 1.1369 - acc: 0.6202 - val_loss: 0.9845 - val_acc: 0.6867
# Epoch 5/90
# 781/781 [==============================] - 35s 44ms/step - loss: 1.0324 - acc: 0.6626 - val_loss: 0.8959 - val_acc: 0.7201
# Epoch 6/90
# 781/781 [==============================] - 35s 45ms/step - loss: 0.9637 - acc: 0.6896 - val_loss: 0.8793 - val_acc: 0.7249
# Epoch 7/90
# 781/781 [==============================] - 35s 44ms/step - loss: 0.9135 - acc: 0.7073 - val_loss: 0.8235 - val_acc: 0.7523
# Epoch 8/90
# 781/781 [==============================] - 35s 45ms/step - loss: 0.8702 - acc: 0.7259 - val_loss: 0.7572 - val_acc: 0.7766
# Epoch 9/90
# 781/781 [==============================] - 35s 45ms/step - loss: 0.8459 - acc: 0.7407 - val_loss: 0.7165 - val_acc: 0.7916
# Epoch 10/90
# 781/781 [==============================] - 35s 44ms/step - loss: 0.8172 - acc: 0.7523 - val_loss: 0.7204 - val_acc: 0.7880
# Epoch 11/90
# 781/781 [==============================] - 35s 44ms/step - loss: 0.7899 - acc: 0.7677 - val_loss: 0.7692 - val_acc: 0.7781
# Epoch 12/90
# 781/781 [==============================] - 35s 45ms/step - loss: 0.7815 - acc: 0.7717 - val_loss: 0.7203 - val_acc: 0.7981
# Epoch 13/90
# 781/781 [==============================] - 35s 45ms/step - loss: 0.7635 - acc: 0.7784 - val_loss: 0.6820 - val_acc: 0.8112
# Epoch 14/90
# 781/781 [==============================] - 34s 44ms/step - loss: 0.7532 - acc: 0.7845 - val_loss: 0.7071 - val_acc: 0.8060
# Epoch 15/90
# 781/781 [==============================] - 35s 45ms/step - loss: 0.7375 - acc: 0.7924 - val_loss: 0.6952 - val_acc: 0.8135
# Epoch 16/90
# 781/781 [==============================] - 35s 45ms/step - loss: 0.7368 - acc: 0.7924 - val_loss: 0.7595 - val_acc: 0.7939
# Epoch 17/90
# 781/781 [==============================] - 34s 44ms/step - loss: 0.7223 - acc: 0.7986 - val_loss: 0.6312 - val_acc: 0.8289
# Epoch 18/90
# 781/781 [==============================] - 35s 45ms/step - loss: 0.7155 - acc: 0.8015 - val_loss: 0.6706 - val_acc: 0.8217
# Epoch 19/90
# 781/781 [==============================] - 35s 45ms/step - loss: 0.7099 - acc: 0.8051 - val_loss: 0.6408 - val_acc: 0.8298
# Epoch 20/90
# 781/781 [==============================] - 35s 45ms/step - loss: 0.6970 - acc: 0.8110 - val_loss: 0.6174 - val_acc: 0.8392
# Epoch 21/90
# 781/781 [==============================] - 35s 45ms/step - loss: 0.6962 - acc: 0.8118 - val_loss: 0.6560 - val_acc: 0.8267
# Epoch 22/90
# 781/781 [==============================] - 35s 45ms/step - loss: 0.6918 - acc: 0.8140 - val_loss: 0.6180 - val_acc: 0.8390
# Epoch 23/90
# 781/781 [==============================] - 35s 45ms/step - loss: 0.6824 - acc: 0.8144 - val_loss: 0.6282 - val_acc: 0.8348
# Epoch 24/90
# 781/781 [==============================] - 35s 45ms/step - loss: 0.6840 - acc: 0.8167 - val_loss: 0.7148 - val_acc: 0.8195
# Epoch 25/90
# 781/781 [==============================] - 35s 45ms/step - loss: 0.6769 - acc: 0.8208 - val_loss: 0.6377 - val_acc: 0.8376
# Epoch 26/90
# 781/781 [==============================] - 35s 45ms/step - loss: 0.6746 - acc: 0.8198 - val_loss: 0.6157 - val_acc: 0.8470
# Epoch 27/90
# 781/781 [==============================] - 35s 44ms/step - loss: 0.6686 - acc: 0.8236 - val_loss: 0.6074 - val_acc: 0.8455
# Epoch 28/90
# 781/781 [==============================] - 36s 46ms/step - loss: 0.6678 - acc: 0.8244 - val_loss: 0.6150 - val_acc: 0.8463
# Epoch 29/90
# 781/781 [==============================] - 36s 46ms/step - loss: 0.6650 - acc: 0.8252 - val_loss: 0.6581 - val_acc: 0.8304
# Epoch 30/90
# 781/781 [==============================] - 36s 46ms/step - loss: 0.6614 - acc: 0.8265 - val_loss: 0.6513 - val_acc: 0.8366
# Epoch 31/90
# 781/781 [==============================] - 35s 45ms/step - loss: 0.6564 - acc: 0.8300 - val_loss: 0.5822 - val_acc: 0.8618
# Epoch 32/90
# 781/781 [==============================] - 35s 45ms/step - loss: 0.6574 - acc: 0.8290 - val_loss: 0.6100 - val_acc: 0.8461
# Epoch 33/90
# 781/781 [==============================] - 36s 46ms/step - loss: 0.6518 - acc: 0.8318 - val_loss: 0.6289 - val_acc: 0.8413
# Epoch 34/90
# 781/781 [==============================] - 34s 44ms/step - loss: 0.6492 - acc: 0.8320 - val_loss: 0.6191 - val_acc: 0.8474
# Epoch 35/90
# 781/781 [==============================] - 35s 44ms/step - loss: 0.6401 - acc: 0.8352 - val_loss: 0.6243 - val_acc: 0.8460
# Epoch 36/90
# 781/781 [==============================] - 34s 43ms/step - loss: 0.6494 - acc: 0.8335 - val_loss: 0.6130 - val_acc: 0.8485
# Epoch 37/90
# 781/781 [==============================] - 34s 43ms/step - loss: 0.6422 - acc: 0.8351 - val_loss: 0.5813 - val_acc: 0.8599
# Epoch 38/90
# 781/781 [==============================] - 33s 43ms/step - loss: 0.6427 - acc: 0.8349 - val_loss: 0.6258 - val_acc: 0.8457
# Epoch 39/90
# 781/781 [==============================] - 33s 42ms/step - loss: 0.6314 - acc: 0.8396 - val_loss: 0.6131 - val_acc: 0.8485
# Epoch 40/90
# 781/781 [==============================] - 33s 42ms/step - loss: 0.6341 - acc: 0.8366 - val_loss: 0.6051 - val_acc: 0.8480
# Epoch 41/90
# 781/781 [==============================] - 33s 42ms/step - loss: 0.6309 - acc: 0.8384 - val_loss: 0.6111 - val_acc: 0.8486
# Epoch 42/90
# 781/781 [==============================] - 33s 43ms/step - loss: 0.6322 - acc: 0.8401 - val_loss: 0.6172 - val_acc: 0.8496
# Epoch 43/90
# 781/781 [==============================] - 34s 44ms/step - loss: 0.6331 - acc: 0.8384 - val_loss: 0.6443 - val_acc: 0.8398
# Epoch 44/90
# 781/781 [==============================] - 35s 44ms/step - loss: 0.6281 - acc: 0.8402 - val_loss: 0.6079 - val_acc: 0.8480
# Epoch 45/90
# 781/781 [==============================] - 35s 44ms/step - loss: 0.6235 - acc: 0.8426 - val_loss: 0.6736 - val_acc: 0.8355
# Epoch 46/90
# 781/781 [==============================] - 34s 44ms/step - loss: 0.6248 - acc: 0.8422 - val_loss: 0.6373 - val_acc: 0.8407
# Epoch 47/90
# 781/781 [==============================] - 34s 43ms/step - loss: 0.6254 - acc: 0.8431 - val_loss: 0.5855 - val_acc: 0.8604
# Epoch 48/90
# 781/781 [==============================] - 34s 44ms/step - loss: 0.6165 - acc: 0.8444 - val_loss: 0.5868 - val_acc: 0.8611
# Epoch 49/90
# 781/781 [==============================] - 35s 45ms/step - loss: 0.6182 - acc: 0.8443 - val_loss: 0.5835 - val_acc: 0.8582
# Epoch 50/90
# 781/781 [==============================] - 33s 42ms/step - loss: 0.6173 - acc: 0.8465 - val_loss: 0.6268 - val_acc: 0.8496
# Epoch 51/90
# 781/781 [==============================] - 33s 42ms/step - loss: 0.6176 - acc: 0.8442 - val_loss: 0.6019 - val_acc: 0.8575
# Epoch 52/90
# 781/781 [==============================] - 33s 42ms/step - loss: 0.6157 - acc: 0.8466 - val_loss: 0.5763 - val_acc: 0.8650
# Epoch 53/90
# 781/781 [==============================] - 34s 43ms/step - loss: 0.6072 - acc: 0.8490 - val_loss: 0.6032 - val_acc: 0.8580
# Epoch 54/90
# 781/781 [==============================] - 34s 44ms/step - loss: 0.6153 - acc: 0.8475 - val_loss: 0.5915 - val_acc: 0.8571
# Epoch 55/90
# 781/781 [==============================] - 33s 42ms/step - loss: 0.6092 - acc: 0.8483 - val_loss: 0.5697 - val_acc: 0.8654
# Epoch 56/90
# 781/781 [==============================] - 33s 42ms/step - loss: 0.6135 - acc: 0.8457 - val_loss: 0.6415 - val_acc: 0.8447
# Epoch 57/90
# 781/781 [==============================] - 32s 41ms/step - loss: 0.6019 - acc: 0.8521 - val_loss: 0.5596 - val_acc: 0.8682
# Epoch 58/90
# 781/781 [==============================] - 33s 43ms/step - loss: 0.6130 - acc: 0.8465 - val_loss: 0.5579 - val_acc: 0.8668
# Epoch 59/90
# 781/781 [==============================] - 34s 43ms/step - loss: 0.6040 - acc: 0.8498 - val_loss: 0.5744 - val_acc: 0.8649
# Epoch 60/90
# 781/781 [==============================] - 33s 42ms/step - loss: 0.6099 - acc: 0.8493 - val_loss: 0.5826 - val_acc: 0.8654
# Epoch 61/90
# 781/781 [==============================] - 32s 41ms/step - loss: 0.6082 - acc: 0.8487 - val_loss: 0.5940 - val_acc: 0.8566
# Epoch 62/90
# 781/781 [==============================] - 33s 42ms/step - loss: 0.6014 - acc: 0.8500 - val_loss: 0.6667 - val_acc: 0.8316
# Epoch 63/90
# 781/781 [==============================] - 32s 41ms/step - loss: 0.6022 - acc: 0.8513 - val_loss: 0.5770 - val_acc: 0.8655
# Epoch 64/90
# 781/781 [==============================] - 34s 43ms/step - loss: 0.6042 - acc: 0.8497 - val_loss: 0.5909 - val_acc: 0.8605
# Epoch 65/90
# 781/781 [==============================] - 34s 43ms/step - loss: 0.5970 - acc: 0.8535 - val_loss: 0.5922 - val_acc: 0.8578
# Epoch 66/90
# 781/781 [==============================] - 33s 42ms/step - loss: 0.5980 - acc: 0.8522 - val_loss: 0.5366 - val_acc: 0.8782
# Epoch 67/90
# 781/781 [==============================] - 32s 41ms/step - loss: 0.5939 - acc: 0.8533 - val_loss: 0.6137 - val_acc: 0.8535
# Epoch 68/90
# 781/781 [==============================] - 32s 41ms/step - loss: 0.5969 - acc: 0.8535 - val_loss: 0.5844 - val_acc: 0.8601
# Epoch 69/90
# 781/781 [==============================] - 34s 43ms/step - loss: 0.5939 - acc: 0.8534 - val_loss: 0.5400 - val_acc: 0.8773
# Epoch 70/90
# 781/781 [==============================] - 33s 43ms/step - loss: 0.5939 - acc: 0.8535 - val_loss: 0.5775 - val_acc: 0.8658
# Epoch 71/90
# 781/781 [==============================] - 33s 42ms/step - loss: 0.5905 - acc: 0.8548 - val_loss: 0.5580 - val_acc: 0.8709
# Epoch 72/90
# 781/781 [==============================] - 33s 42ms/step - loss: 0.5905 - acc: 0.8542 - val_loss: 0.6068 - val_acc: 0.8525
# Epoch 73/90
# 781/781 [==============================] - 34s 43ms/step - loss: 0.5859 - acc: 0.8563 - val_loss: 0.5735 - val_acc: 0.8647
# Epoch 74/90
# 781/781 [==============================] - 33s 43ms/step - loss: 0.5927 - acc: 0.8555 - val_loss: 0.5739 - val_acc: 0.8650
# Epoch 75/90
# 781/781 [==============================] - 33s 42ms/step - loss: 0.5879 - acc: 0.8549 - val_loss: 0.5994 - val_acc: 0.8544
# Epoch 76/90
# 781/781 [==============================] - 34s 43ms/step - loss: 0.5844 - acc: 0.8577 - val_loss: 0.5788 - val_acc: 0.8635
# Epoch 77/90
# 781/781 [==============================] - 34s 44ms/step - loss: 0.5893 - acc: 0.8560 - val_loss: 0.5977 - val_acc: 0.8589
# Epoch 78/90
# 781/781 [==============================] - 34s 43ms/step - loss: 0.5871 - acc: 0.8559 - val_loss: 0.5627 - val_acc: 0.8680
# Epoch 79/90
# 781/781 [==============================] - 33s 42ms/step - loss: 0.5809 - acc: 0.8579 - val_loss: 0.5410 - val_acc: 0.8776
# Epoch 80/90
# 781/781 [==============================] - 34s 44ms/step - loss: 0.5829 - acc: 0.8576 - val_loss: 0.5855 - val_acc: 0.8643
# Epoch 81/90
# 781/781 [==============================] - 34s 44ms/step - loss: 0.5846 - acc: 0.8555 - val_loss: 0.5695 - val_acc: 0.8637
# Epoch 82/90
# 781/781 [==============================] - 33s 43ms/step - loss: 0.5810 - acc: 0.8582 - val_loss: 0.5433 - val_acc: 0.8749
# Epoch 83/90
# 781/781 [==============================] - 35s 45ms/step - loss: 0.5806 - acc: 0.8581 - val_loss: 0.5719 - val_acc: 0.8687
# Epoch 84/90
# 781/781 [==============================] - 35s 44ms/step - loss: 0.5844 - acc: 0.8562 - val_loss: 0.5484 - val_acc: 0.8724
# Epoch 85/90
# 781/781 [==============================] - 34s 44ms/step - loss: 0.5822 - acc: 0.8587 - val_loss: 0.5515 - val_acc: 0.8704
# Epoch 86/90
# 781/781 [==============================] - 35s 45ms/step - loss: 0.5758 - acc: 0.8602 - val_loss: 0.5783 - val_acc: 0.8619
# Epoch 87/90
# 781/781 [==============================] - 35s 44ms/step - loss: 0.5767 - acc: 0.8598 - val_loss: 0.5295 - val_acc: 0.8805
# Epoch 88/90
# 781/781 [==============================] - 33s 42ms/step - loss: 0.5759 - acc: 0.8598 - val_loss: 0.5611 - val_acc: 0.8713
# Epoch 89/90
# 781/781 [==============================] - 34s 44ms/step - loss: 0.5744 - acc: 0.8615 - val_loss: 0.5571 - val_acc: 0.8732
# Epoch 90/90
# 781/781 [==============================] - 35s 45ms/step - loss: 0.5802 - acc: 0.8583 - val_loss: 0.5625 - val_acc: 0.8668
# Epoch 1/30
# 781/781 [==============================] - 36s 46ms/step - loss: 0.7797 - acc: 0.8056 - val_loss: 0.7297 - val_acc: 0.8280
# Epoch 2/30
# 781/781 [==============================] - 33s 43ms/step - loss: 0.6663 - acc: 0.8433 - val_loss: 0.6486 - val_acc: 0.8532
# Epoch 3/30
# 781/781 [==============================] - 34s 43ms/step - loss: 0.6356 - acc: 0.8517 - val_loss: 0.6332 - val_acc: 0.8534
# Epoch 4/30
# 781/781 [==============================] - 36s 46ms/step - loss: 0.6153 - acc: 0.8558 - val_loss: 0.6141 - val_acc: 0.8591
# Epoch 5/30
# 781/781 [==============================] - 36s 47ms/step - loss: 0.6102 - acc: 0.8559 - val_loss: 0.5706 - val_acc: 0.8722
# Epoch 6/30
# 781/781 [==============================] - 36s 46ms/step - loss: 0.6011 - acc: 0.8586 - val_loss: 0.5719 - val_acc: 0.8705
# Epoch 7/30
# 781/781 [==============================] - 36s 46ms/step - loss: 0.5945 - acc: 0.8584 - val_loss: 0.5744 - val_acc: 0.8706
# Epoch 8/30
# 781/781 [==============================] - 37s 47ms/step - loss: 0.5917 - acc: 0.8561 - val_loss: 0.6172 - val_acc: 0.8570
# Epoch 9/30
# 781/781 [==============================] - 36s 46ms/step - loss: 0.5859 - acc: 0.8602 - val_loss: 0.6017 - val_acc: 0.8575
# Epoch 10/30
# 781/781 [==============================] - 36s 46ms/step - loss: 0.5840 - acc: 0.8614 - val_loss: 0.5659 - val_acc: 0.8699
# Epoch 11/30
# 781/781 [==============================] - 35s 45ms/step - loss: 0.5804 - acc: 0.8607 - val_loss: 0.5884 - val_acc: 0.8588
# Epoch 12/30
# 781/781 [==============================] - 36s 46ms/step - loss: 0.5768 - acc: 0.8615 - val_loss: 0.5638 - val_acc: 0.8689
# Epoch 13/30
# 781/781 [==============================] - 36s 46ms/step - loss: 0.5764 - acc: 0.8626 - val_loss: 0.5348 - val_acc: 0.8779
# Epoch 14/30
# 781/781 [==============================] - 35s 45ms/step - loss: 0.5754 - acc: 0.8627 - val_loss: 0.5219 - val_acc: 0.8844
# Epoch 15/30
# 781/781 [==============================] - 34s 44ms/step - loss: 0.5739 - acc: 0.8626 - val_loss: 0.5989 - val_acc: 0.8571
# Epoch 16/30
# 781/781 [==============================] - 35s 45ms/step - loss: 0.5745 - acc: 0.8616 - val_loss: 0.5556 - val_acc: 0.8737
# Epoch 17/30
# 781/781 [==============================] - 35s 44ms/step - loss: 0.5711 - acc: 0.8622 - val_loss: 0.5807 - val_acc: 0.8646
# Epoch 18/30
# 781/781 [==============================] - 34s 43ms/step - loss: 0.5727 - acc: 0.8620 - val_loss: 0.5693 - val_acc: 0.8638
# Epoch 19/30
# 781/781 [==============================] - 35s 45ms/step - loss: 0.5615 - acc: 0.8660 - val_loss: 0.6321 - val_acc: 0.8453
# Epoch 20/30
# 781/781 [==============================] - 35s 44ms/step - loss: 0.5665 - acc: 0.8628 - val_loss: 0.5560 - val_acc: 0.8719
# Epoch 21/30
# 781/781 [==============================] - 34s 44ms/step - loss: 0.5629 - acc: 0.8657 - val_loss: 0.5323 - val_acc: 0.8794
# Epoch 22/30
# 781/781 [==============================] - 35s 45ms/step - loss: 0.5547 - acc: 0.8676 - val_loss: 0.5391 - val_acc: 0.8788
# Epoch 23/30
# 781/781 [==============================] - 34s 44ms/step - loss: 0.5625 - acc: 0.8659 - val_loss: 0.5352 - val_acc: 0.8767
# Epoch 24/30
# 781/781 [==============================] - 34s 44ms/step - loss: 0.5606 - acc: 0.8652 - val_loss: 0.5537 - val_acc: 0.8732
# Epoch 25/30
# 781/781 [==============================] - 34s 43ms/step - loss: 0.5635 - acc: 0.8640 - val_loss: 0.5664 - val_acc: 0.8695
# Epoch 26/30
# 781/781 [==============================] - 35s 44ms/step - loss: 0.5566 - acc: 0.8669 - val_loss: 0.5671 - val_acc: 0.8693
# Epoch 27/30
# 781/781 [==============================] - 35s 45ms/step - loss: 0.5571 - acc: 0.8666 - val_loss: 0.5318 - val_acc: 0.8838
# Epoch 28/30
# 781/781 [==============================] - 36s 45ms/step - loss: 0.5609 - acc: 0.8673 - val_loss: 0.5584 - val_acc: 0.8697
# Epoch 29/30
# 781/781 [==============================] - 35s 45ms/step - loss: 0.5559 - acc: 0.8653 - val_loss: 0.5643 - val_acc: 0.8714
# Epoch 30/30
# 781/781 [==============================] - 35s 45ms/step - loss: 0.5539 - acc: 0.8682 - val_loss: 0.5701 - val_acc: 0.8647
# Epoch 1/30
# 781/781 [==============================] - 37s 47ms/step - loss: 0.5284 - acc: 0.8788 - val_loss: 0.5123 - val_acc: 0.8853
# Epoch 2/30
# 781/781 [==============================] - 35s 45ms/step - loss: 0.5123 - acc: 0.8817 - val_loss: 0.5031 - val_acc: 0.8905
# Epoch 3/30
# 781/781 [==============================] - 36s 46ms/step - loss: 0.5050 - acc: 0.8850 - val_loss: 0.4995 - val_acc: 0.8914
# Epoch 4/30
# 781/781 [==============================] - 36s 46ms/step - loss: 0.5007 - acc: 0.8855 - val_loss: 0.4951 - val_acc: 0.8935
# Epoch 5/30
# 781/781 [==============================] - 35s 45ms/step - loss: 0.4960 - acc: 0.8867 - val_loss: 0.4911 - val_acc: 0.8947
# Epoch 6/30
# 781/781 [==============================] - 36s 46ms/step - loss: 0.4867 - acc: 0.8901 - val_loss: 0.4914 - val_acc: 0.8938
# Epoch 7/30
# 781/781 [==============================] - 37s 47ms/step - loss: 0.4916 - acc: 0.8884 - val_loss: 0.4885 - val_acc: 0.8951
# Epoch 8/30
# 781/781 [==============================] - 37s 47ms/step - loss: 0.4855 - acc: 0.8906 - val_loss: 0.4868 - val_acc: 0.8952
# Epoch 9/30
# 781/781 [==============================] - 37s 47ms/step - loss: 0.4845 - acc: 0.8902 - val_loss: 0.4856 - val_acc: 0.8956
# Epoch 10/30
# 781/781 [==============================] - 36s 46ms/step - loss: 0.4832 - acc: 0.8920 - val_loss: 0.4841 - val_acc: 0.8965
# Epoch 11/30
# 781/781 [==============================] - 36s 46ms/step - loss: 0.4789 - acc: 0.8931 - val_loss: 0.4805 - val_acc: 0.8969
# Epoch 12/30
# 781/781 [==============================] - 36s 46ms/step - loss: 0.4796 - acc: 0.8915 - val_loss: 0.4844 - val_acc: 0.8961
# Epoch 13/30
# 781/781 [==============================] - 37s 47ms/step - loss: 0.4741 - acc: 0.8942 - val_loss: 0.4814 - val_acc: 0.8971
# Epoch 14/30
# 781/781 [==============================] - 37s 47ms/step - loss: 0.4783 - acc: 0.8926 - val_loss: 0.4811 - val_acc: 0.8975
# Epoch 15/30
# 781/781 [==============================] - 36s 47ms/step - loss: 0.4727 - acc: 0.8943 - val_loss: 0.4801 - val_acc: 0.8964
# Epoch 16/30
# 781/781 [==============================] - 37s 48ms/step - loss: 0.4720 - acc: 0.8948 - val_loss: 0.4789 - val_acc: 0.8972
# Epoch 17/30
# 781/781 [==============================] - 37s 48ms/step - loss: 0.4675 - acc: 0.8958 - val_loss: 0.4803 - val_acc: 0.8972
# Epoch 18/30
# 781/781 [==============================] - 37s 48ms/step - loss: 0.4688 - acc: 0.8957 - val_loss: 0.4777 - val_acc: 0.8984
# Epoch 19/30
# 781/781 [==============================] - 38s 48ms/step - loss: 0.4685 - acc: 0.8952 - val_loss: 0.4758 - val_acc: 0.8991
# Epoch 20/30
# 781/781 [==============================] - 37s 48ms/step - loss: 0.4705 - acc: 0.8940 - val_loss: 0.4761 - val_acc: 0.8987
# Epoch 21/30
# 781/781 [==============================] - 37s 47ms/step - loss: 0.4658 - acc: 0.8962 - val_loss: 0.4738 - val_acc: 0.8994
# Epoch 22/30
# 781/781 [==============================] - 35s 45ms/step - loss: 0.4636 - acc: 0.8964 - val_loss: 0.4760 - val_acc: 0.8990
# Epoch 23/30
# 781/781 [==============================] - 36s 46ms/step - loss: 0.4618 - acc: 0.8987 - val_loss: 0.4736 - val_acc: 0.8987
# Epoch 24/30
# 781/781 [==============================] - 36s 46ms/step - loss: 0.4624 - acc: 0.8971 - val_loss: 0.4715 - val_acc: 0.9001
# Epoch 25/30
# 781/781 [==============================] - 36s 46ms/step - loss: 0.4616 - acc: 0.8973 - val_loss: 0.4745 - val_acc: 0.8998
# Epoch 26/30
# 781/781 [==============================] - 36s 46ms/step - loss: 0.4564 - acc: 0.8994 - val_loss: 0.4706 - val_acc: 0.9001
# Epoch 27/30
# 781/781 [==============================] - 36s 46ms/step - loss: 0.4577 - acc: 0.8985 - val_loss: 0.4719 - val_acc: 0.8999
# Epoch 28/30
# 781/781 [==============================] - 35s 45ms/step - loss: 0.4555 - acc: 0.8999 - val_loss: 0.4703 - val_acc: 0.9002
# Epoch 29/30
# 781/781 [==============================] - 36s 46ms/step - loss: 0.4613 - acc: 0.8975 - val_loss: 0.4687 - val_acc: 0.9008
# Epoch 30/30
# 781/781 [==============================] - 35s 45ms/step - loss: 0.4574 - acc: 0.8993 - val_loss: 0.4691 - val_acc: 0.9002
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-2-102ceb826566> in <module>()
#      88         metrics=['accuracy'])
#      89 model.fit_generator(datagen.flow(x_train, y_train, batch_size=batch_size),steps_per_epoch=x_train.shape[0] // batch_size,epochs=epochs,verbose=1,validation_data=(x_test,y_test))
# ---> 90 model = keras.models.load_model('v3_Adam.py')
#      91 scores = model.evaluate(x_test, y_test, batch_size=128, verbose=1)
#      92 print('\nTest result: %.3f loss: %.3f' % (scores[1]*100,scores[0]))
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py in load_wrapper(*args, **kwargs)
#     456                 os.remove(tmp_filepath)
#     457             return res
# --> 458         return load_function(*args, **kwargs)
#     459
#     460     return load_wrapper
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py in load_model(filepath, custom_objects, compile)
#     547
#     548     if H5Dict.is_supported_type(filepath):
# --> 549         with H5Dict(filepath, mode='r') as h5dict:
#     550             model = _deserialize_model(h5dict, custom_objects, compile)
#     551     elif hasattr(filepath, 'write') and callable(filepath.write):
#
# /usr/local/lib/python3.6/dist-packages/keras/utils/io_utils.py in __init__(self, path, mode)
#     189             self._is_file = False
#     190         elif isinstance(path, six.string_types) or _is_path_instance(path):
# --> 191             self.data = h5py.File(path, mode=mode)
#     192             self._is_file = True
#     193         elif isinstance(path, dict):
#
# /usr/local/lib/python3.6/dist-packages/h5py/_hl/files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, **kwds)
#     310             with phil:
#     311                 fapl = make_fapl(driver, libver, **kwds)
# --> 312                 fid = make_fid(name, mode, userblock_size, fapl, swmr=swmr)
#     313
#     314                 if swmr_support:
#
# /usr/local/lib/python3.6/dist-packages/h5py/_hl/files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     140         if swmr and swmr_support:
#     141             flags |= h5f.ACC_SWMR_READ
# --> 142         fid = h5f.open(name, flags, fapl=fapl)
#     143     elif mode == 'r+':
#     144         fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5f.pyx in h5py.h5f.open()
#
# OSError: Unable to open file (unable to open file: name = 'v3_Adam.py', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)

# %%
import matplotlib.pyplot as plt
import matplotlib

plt.figure(figsize=(20,10))
plt.plot(hist['acc'],'-.',linewidth=4.5,label = 'train accuracy')
plt.plot(hist['val_acc'],'-.',linewidth=4.5,label = 'test accuracy ')


plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend()
plt.grid()



matplotlib.rcParams.update({'font.size': 25})
plt.show()
